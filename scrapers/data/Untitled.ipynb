# %%
import json
import pandas as pd

# ✅ Charge le fichier JSON — remplace le nom par le tien
with open("jumia_2026-03-30T09-33-29+00-00.json", encoding="utf-8") as f:
    data = json.load(f)

# ✅ Convertit en tableau
df = pd.DataFrame(data)

# ✅ Affiche les infos générales
print("=== INFOS GÉNÉRALES ===")
print(f"Total produits : {len(df)}")
print(f"\nProduits par catégorie :")
print(df["category"].value_counts())
print(f"\nProduits par source :")
print(df["source"].value_counts())
# Out:
# === INFOS GÉNÉRALES ===
# Total produits : 800
#
# Produits par catégorie :
# category
# smartphones    200
# laptops        200
# tv             200
# vetements      200
# Name: count, dtype: int64
#
# Produits par source :
# source
# jumia    800
# Name: count, dtype: int64

# %%
# ✅ Vérifie les valeurs manquantes
print("=== VALEURS MANQUANTES ===")
print(df.isnull().sum())

print("\n=== APERÇU DES DONNÉES ===")
df.head(10)
# Out:
# === VALEURS MANQUANTES ===
# name           0
# price        800
# category       0
# source         0
# url            0
# timestamp      0
# dtype: int64
#
# === APERÇU DES DONNÉES ===
#   name price     category source  \
# 0       None  smartphones  jumia
# 1       None  smartphones  jumia
# 2       None  smartphones  jumia
# 3       None  smartphones  jumia
# 4       None  smartphones  jumia
# 5       None  smartphones  jumia
# 6       None  smartphones  jumia
# 7       None  smartphones  jumia
# 8       None  smartphones  jumia
# 9       None  smartphones  jumia
#
#                                                  url  \
# 0  https://www.jumia.ma/samsung-a07-67-64-gb-4-gb...
# 1  https://www.jumia.ma/itel-a100c-6.6-6gb-24-ram...
# 2  https://www.jumia.ma/samsung-galaxy-a16-8gb-25...
# 3  https://www.jumia.ma/xiaomi-redmi-note-15-6gb-...
# 4  https://www.jumia.ma/samsung-galaxy-a06-67-128...
# 5  https://www.jumia.ma/xiaomi-redmi-15c-6.9-4gb-...
# 6  https://www.jumia.ma/tecno-spark-40c-66-128go-...
# 7  https://www.jumia.ma/xiaomi-redmi-15c-6.9-6gb-...
# 8  https://www.jumia.ma/oppo-a5i-6.67-4gb128gb-ip...
# 9  https://www.jumia.ma/itel-a100c-6.6-8gb-35-ram...
#
#                     timestamp
# 0  2026-03-30T09:33:34.316771
# 1  2026-03-30T09:33:34.330216
# 2  2026-03-30T09:33:34.332507
# 3  2026-03-30T09:33:34.335946
# 4  2026-03-30T09:33:34.338220
# 5  2026-03-30T09:33:34.341774
# 6  2026-03-30T09:33:34.344801
# 7  2026-03-30T09:33:34.347794
# 8  2026-03-30T09:33:34.350336
# 9  2026-03-30T09:33:34.355366

# %%
# ✅ Vérifie les prix
print("=== STATISTIQUES DES PRIX ===")
print(df["price"].describe())

print("\n=== EXEMPLE DE PRODUITS ===")
for cat in df["category"].unique():
    print(f"\n--- {cat.upper()} ---")
    print(df[df["category"]==cat][["name","price"]].head(3).to_string())
# Out:
# === STATISTIQUES DES PRIX ===
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: price, dtype: object
#
# === EXEMPLE DE PRODUITS ===
#
# --- SMARTPHONES ---
#   name price
# 0       None
# 1       None
# 2       None
#
# --- LAPTOPS ---
#    name price
# 71       None
# 72       None
# 73       None
#
# --- TV ---
#     name price
# 125       None
# 126       None
# 127       None
#
# --- VETEMENTS ---
#     name price
# 210       None
# 211       None
# 212       None

# %%
with open("jumia_2026-03-30T10-13-56+00-00.json", encoding="utf-8") as f:
    data = json.load(f)

df = pd.DataFrame(data)

# Vérifie les valeurs manquantes
print("=== VALEURS MANQUANTES ===")
print(df.isnull().sum())

print("\n=== EXEMPLE DE PRODUITS ===")
for cat in df["category"].unique():
    print(f"\n--- {cat.upper()} ---")
    print(df[df["category"]==cat][["name","price"]].head(3).to_string())
# Out:
# === VALEURS MANQUANTES ===
# name            0
# price        1000
# category        0
# source          0
# url             0
# timestamp       0
# dtype: int64
#
# === EXEMPLE DE PRODUITS ===
#
# --- SMARTPHONES ---
#                                                  name price
# 0               A07 – 6,7" – 64 GB + 4 GB Ram – Green  None
# 1         A100C 6.6’’ – 6GB (2+4) RAM + 64 ROM – Noir  None
# 2  Galaxy A16 8GB + 256GB - Black - 2 ans de garantie  None
#
# --- LAPTOPS ---
#                                                                                                    name price
# 71  IdeaPad Slim 5 14IMH9 Ultra 7-155H 14" WUXGA - 16 Go + 512 Go SSD - Win 11 Home CLOUD GREY - Neuf -  None
# 72     ExpertBook P1503CVA - i5-13420H - 15.6" FHD - 8Go RAM + 512Go SSD - Freedos - Neuf -1An Garantie  None
# 73                         Optiplex 3020 MT Intel Celeron @ 2.7GHz - RAM 4Go , HDD 250Go (Remis à Neuf)  None
#
# --- TV ---
#                                                                                            name price
# 125               Smart TV Android 32” – Android 14.0 , Dolby Audio , HD 720 , Wi-Fi, HDMI, USB  None
# 126  32 QLED Full HD Smart Google TV, Dolby Audio, Design sans bordure + Support Gratuit, 32S5K  None
# 127                    32 HD LED Sans Cadre, HDMI, USB, Récepteur intégré + TNT + Support Mural  None
#
# --- VETEMENTS ---
#                                        name price
# 210  T-Shirt Pour Femmes 100% Cotton - Noir  None
# 211        Top Pour Femmes Polyester - Kaki  None
# 212       Top Pour Femmes Polyester - Beige  None

# %%
import json
import pandas as pd

# ✅ Charge le nouveau fichier
with open("jumia_2026-03-30T10-19-39+00-00.json", encoding="utf-8") as f:
    data = json.load(f)

df = pd.DataFrame(data)

# ✅ Vérifie les valeurs manquantes
print("=== VALEURS MANQUANTES ===")
print(df.isnull().sum())

# ✅ Vérifie les prix
print("\n=== STATISTIQUES PRIX ===")
print(df["price"].describe())

# ✅ Affiche 3 exemples par catégorie
print("\n=== EXEMPLES PAR CATÉGORIE ===")
for cat in df["category"].unique():
    print(f"\n--- {cat.upper()} ---")
    print(df[df["category"]==cat][["name","price"]].head(3).to_string())
# Out:
# === VALEURS MANQUANTES ===
# name           0
# price        510
# category       0
# source         0
# url            0
# timestamp      0
# dtype: int64
#
# === STATISTIQUES PRIX ===
# count    490.000000
# mean     201.259673
# std      244.461950
# min       19.000000
# 25%       66.750000
# 50%      109.000000
# 75%      180.000000
# max      999.000000
# Name: price, dtype: float64
#
# === EXEMPLES PAR CATÉGORIE ===
#
# --- SMARTPHONES ---
#                                                  name  price
# 0               A07 – 6,7" – 64 GB + 4 GB Ram – Green  949.0
# 1         A100C 6.6’’ – 6GB (2+4) RAM + 64 ROM – Noir  799.0
# 2  Galaxy A16 8GB + 256GB - Black - 2 ans de garantie    NaN
#
# --- LAPTOPS ---
#                                                                                                    name  price
# 71  IdeaPad Slim 5 14IMH9 Ultra 7-155H 14" WUXGA - 16 Go + 512 Go SSD - Win 11 Home CLOUD GREY - Neuf -    NaN
# 72     ExpertBook P1503CVA - i5-13420H - 15.6" FHD - 8Go RAM + 512Go SSD - Freedos - Neuf -1An Garantie    NaN
# 73                         Optiplex 3020 MT Intel Celeron @ 2.7GHz - RAM 4Go , HDD 250Go (Remis à Neuf)  399.0
#
# --- TV ---
#                                                                                            name  price
# 125               Smart TV Android 32” – Android 14.0 , Dolby Audio , HD 720 , Wi-Fi, HDMI, USB  999.0
# 126  32 QLED Full HD Smart Google TV, Dolby Audio, Design sans bordure + Support Gratuit, 32S5K    NaN
# 127                    32 HD LED Sans Cadre, HDMI, USB, Récepteur intégré + TNT + Support Mural  950.0
#
# --- VETEMENTS ---
#                                        name  price
# 210  T-Shirt Pour Femmes 100% Cotton - Noir  113.0
# 211        Top Pour Femmes Polyester - Kaki   86.0
# 212       Top Pour Femmes Polyester - Beige  124.0

# %%
import json
import pandas as pd

# ✅ Charge le fichier — remplace par ton nom de fichier exact
with open("jumia_2026-03-30T10-27-09+00-00.json", encoding="utf-8") as f:
    data = json.load(f)

df = pd.DataFrame(data)

# ==============================
# 1. INFOS GÉNÉRALES
# ==============================
print("=== INFOS GÉNÉRALES ===")
print(f"Total produits    : {len(df)}")
print(f"Colonnes          : {list(df.columns)}")

# ==============================
# 2. PRODUITS PAR CATÉGORIE
# ==============================
print("\n=== PRODUITS PAR CATÉGORIE ===")
print(df["category"].value_counts())

# ==============================
# 3. VALEURS MANQUANTES
# ==============================
print("\n=== VALEURS MANQUANTES ===")
print(df.isnull().sum())

# ==============================
# 4. STATISTIQUES DES PRIX
# ==============================
print("\n=== STATISTIQUES PRIX (en Dhs) ===")
print(df["price"].describe().round(2))

# ==============================
# 5. PRIX PAR CATÉGORIE
# ==============================
print("\n=== PRIX MOYEN PAR CATÉGORIE ===")
print(df.groupby("category")["price"].mean().round(2))

# ==============================
# 6. PRODUITS SANS PRIX
# ==============================
missing_price = df[df["price"].isnull()]
print(f"\n=== PRODUITS SANS PRIX : {len(missing_price)} ===")
if len(missing_price) > 0:
    print(missing_price[["name", "category", "price"]].head(5))

# ==============================
# 7. PRODUITS SANS NOM
# ==============================
missing_name = df[df["name"] == ""]
print(f"\n=== PRODUITS SANS NOM : {len(missing_name)} ===")
if len(missing_name) > 0:
    print(missing_name[["name", "category", "price"]].head(5))

# ==============================
# 8. EXEMPLES PAR CATÉGORIE
# ==============================
print("\n=== 3 EXEMPLES PAR CATÉGORIE ===")
for cat in df["category"].unique():
    print(f"\n--- {cat.upper()} ---")
    print(df[df["category"] == cat][["name", "price", "url"]].head(3).to_string())

# ==============================
# 9. VÉRIFICATION URLS
# ==============================
print("\n=== VÉRIFICATION URLS ===")
urls_valides = df["url"].str.startswith("https://www.jumia.ma").sum()
print(f"URLs valides : {urls_valides}/{len(df)}")

# ==============================
# 10. APERÇU FINAL
# ==============================
print("\n=== APERÇU FINAL ===")
df.head(10)
# Out:
# === INFOS GÉNÉRALES ===
# Total produits    : 1000
# Colonnes          : ['name', 'price', 'category', 'source', 'url', 'timestamp']
#
# === PRODUITS PAR CATÉGORIE ===
# category
# smartphones    250
# laptops        250
# tv             250
# vetements      250
# Name: count, dtype: int64
#
# === VALEURS MANQUANTES ===
# name          0
# price        10
# category      0
# source        0
# url           0
# timestamp     0
# dtype: int64
#
# === STATISTIQUES PRIX (en Dhs) ===
# count      990.00
# mean      2122.21
# std       4199.93
# min         19.00
# 25%        110.00
# 50%       1073.00
# 75%       2499.00
# max      52726.00
# Name: price, dtype: float64
#
# === PRIX MOYEN PAR CATÉGORIE ===
# category
# laptops        3723.68
# smartphones     813.79
# tv             3840.44
# vetements       102.57
# Name: price, dtype: float64
#
# === PRODUITS SANS PRIX : 10 ===
#                                    name   category  price
# 101    Kit starter Raspberry Pi 5 + M.2    laptops    NaN
# 225  Pantalon Jean Charlie - Bleu Foncé  vetements    NaN
# 232  Pantalon Jean Charlie - Bleu Clair  vetements    NaN
# 235       Pantalon Jean Charlie - Dirty  vetements    NaN
# 335                Carte Raspberry pi 5    laptops    NaN
#
# === PRODUITS SANS NOM : 0 ===
#
# === 3 EXEMPLES PAR CATÉGORIE ===
#
# --- SMARTPHONES ---
#                                                  name   price                                                                                      url
# 0               A07 – 6,7" – 64 GB + 4 GB Ram – Green   949.0                   https://www.jumia.ma/samsung-a07-67-64-gb-4-gb-ram-green-67237287.html
# 1         A100C 6.6’’ – 6GB (2+4) RAM + 64 ROM – Noir   799.0                 https://www.jumia.ma/itel-a100c-6.6-6gb-24-ram-64-rom-noir-67607570.html
# 2  Galaxy A16 8GB + 256GB - Black - 2 ans de garantie  1979.0  https://www.jumia.ma/samsung-galaxy-a16-8gb-256gb-black-2-ans-de-garantie-65981498.html
#
# --- LAPTOPS ---
#                                                                                                    name    price                                                                                                                                                url
# 71  IdeaPad Slim 5 14IMH9 Ultra 7-155H 14" WUXGA - 16 Go + 512 Go SSD - Win 11 Home CLOUD GREY - Neuf -  10999.0  https://www.jumia.ma/lenovo-ideapad-slim-5-14imh9-ultra-7-155h-14-wuxga-16-go-512-go-ssd-win-11-home-cloud-grey-neuf-2-ans-garantie-67395823.html
# 72     ExpertBook P1503CVA - i5-13420H - 15.6" FHD - 8Go RAM + 512Go SSD - Freedos - Neuf -1An Garantie   5899.0                         https://www.jumia.ma/asus-expertbook-p1503cva-i5-13420h-15.6-fhd-8go-ram-512go-ssd-freedos-neuf-1an-garantie-67315766.html
# 73                         Optiplex 3020 MT Intel Celeron @ 2.7GHz - RAM 4Go , HDD 250Go (Remis à Neuf)    399.0                                  https://www.jumia.ma/optiplex-3020-mt-intel-celeron-at-2.7ghz-ram-4go-hdd-500go-remis-a-neuf-dell-mpg1407460.html
#
# --- TV ---
#                                                                                            name   price                                                                                                                             url
# 125               Smart TV Android 32” – Android 14.0 , Dolby Audio , HD 720 , Wi-Fi, HDMI, USB   999.0                    https://www.jumia.ma/tenten-smart-tv-android-32-android-14.0-dolby-audio-hd-720-wi-fi-hdmi-usb-67154065.html
# 126  32 QLED Full HD Smart Google TV, Dolby Audio, Design sans bordure + Support Gratuit, 32S5K  1439.0  https://www.jumia.ma/32-qled-full-hd-smart-google-tv-dolby-audio-design-sans-bordure-support-gratuit-32s5k-tcl-mpg1544971.html
# 127                    32 HD LED Sans Cadre, HDMI, USB, Récepteur intégré + TNT + Support Mural   950.0                      https://www.jumia.ma/visio-32-hd-led-sans-cadre-hdmi-usb-recepteur-integre-tnt-support-mural-67387271.html
#
# --- VETEMENTS ---
#                                        name  price                                                                              url
# 210  T-Shirt Pour Femmes 100% Cotton - Noir  113.0  https://www.jumia.ma/trendyol-t-shirt-pour-femmes-100-cotton-noir-66374557.html
# 211        Top Pour Femmes Polyester - Kaki   86.0       https://www.jumia.ma/trendyol-top-pour-femmes-polyester-kaki-66375066.html
# 212       Top Pour Femmes Polyester - Beige  124.0      https://www.jumia.ma/trendyol-top-pour-femmes-polyester-beige-66375015.html
#
# === VÉRIFICATION URLS ===
# URLs valides : 1000/1000
#
# === APERÇU FINAL ===
#                                                 name   price     category  \
# 0              A07 – 6,7" – 64 GB + 4 GB Ram – Green   949.0  smartphones
# 1        A100C 6.6’’ – 6GB (2+4) RAM + 64 ROM – Noir   799.0  smartphones
# 2  Galaxy A16 8GB + 256GB - Black - 2 ans de gara...  1979.0  smartphones
# 3               Redmi Note 15 6GB 128GB Glacier Blue  2039.0  smartphones
# 4       Galaxy A06 - 6,7" - 128 Go - 6 Go RAM – Noir  1129.0  smartphones
# 5      Redmi 15C 6.9" – 4GB + 128GB - Midnight Black  1199.0  smartphones
# 6  Spark 40C - 6,6'' 128Go + RAM 4GB jusqu'à 16 G...  1129.0  smartphones
# 7          Redmi 15C 6.9" – 6GB + 128GB – Mint Green  1329.0  smartphones
# 8  A5i - 6.67" (4GB+128GB) - IP54 - 5100mAh + 45W...  1199.0  smartphones
# 9        A100C 6.6’’ – 8GB (3+5) RAM +128 ROM – Noir   929.0  smartphones
#
#   source                                                url  \
# 0  jumia  https://www.jumia.ma/samsung-a07-67-64-gb-4-gb...
# 1  jumia  https://www.jumia.ma/itel-a100c-6.6-6gb-24-ram...
# 2  jumia  https://www.jumia.ma/samsung-galaxy-a16-8gb-25...
# 3  jumia  https://www.jumia.ma/xiaomi-redmi-note-15-6gb-...
# 4  jumia  https://www.jumia.ma/samsung-galaxy-a06-67-128...
# 5  jumia  https://www.jumia.ma/xiaomi-redmi-15c-6.9-4gb-...
# 6  jumia  https://www.jumia.ma/tecno-spark-40c-66-128go-...
# 7  jumia  https://www.jumia.ma/xiaomi-redmi-15c-6.9-6gb-...
# 8  jumia  https://www.jumia.ma/oppo-a5i-6.67-4gb128gb-ip...
# 9  jumia  https://www.jumia.ma/itel-a100c-6.6-8gb-35-ram...
#
#                     timestamp
# 0  2026-03-30T10:27:13.498929
# 1  2026-03-30T10:27:13.503471
# 2  2026-03-30T10:27:13.504469
# 3  2026-03-30T10:27:13.506469
# 4  2026-03-30T10:27:13.508468
# 5  2026-03-30T10:27:13.509988
# 6  2026-03-30T10:27:13.512029
# 7  2026-03-30T10:27:13.514050
# 8  2026-03-30T10:27:13.516049
# 9  2026-03-30T10:27:13.517049

# %%
# ✅ Supprimer les produits sans prix
df_clean = df.dropna(subset=["price"])

print(f"Avant nettoyage : {len(df)} produits")
print(f"Après nettoyage : {len(df_clean)} produits")
print(f"Supprimés       : {len(df) - len(df_clean)} produits")

# ✅ Sauvegarder le fichier propre
df_clean.to_json(
    "jumia_clean.json",
    orient="records",
    force_ascii=False,
    indent=2
)

print("\n✅ Fichier sauvegardé : jumia_clean.json")
# Out:
# Avant nettoyage : 1000 produits
# Après nettoyage : 990 produits
# Supprimés       : 10 produits
#
# ✅ Fichier sauvegardé : jumia_clean.json

# %%
import json

with open(r'C:\Users\TonNom\Desktop\price-intelligence-platform\scrapers\data\avito_2026-03-30T12-08-43+00-00.json', 'r', encoding='utf-8') as f:
    contenu = f.read()

contenu_repare = contenu.rstrip().rstrip(',') + ']'

try:
    donnees = json.loads(contenu_repare)
    print(f"✅ {len(donnees)} entrées récupérées")
    
    with open(r'C:\Users\TonNom\Desktop\avito_repare.json', 'w', encoding='utf-8') as f:
        json.dump(donnees, f, ensure_ascii=False, indent=2)
except Exception as e:
    print(f"❌ Erreur : {e}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 import json
# ----> 3 with open(r'C:\Users\TonNom\Desktop\price-intelligence-platform\scrapers\data\avito_2026-03-30T12-08-43+00-00.json', 'r', encoding='utf-8') as f:
#       4     contenu = f.read()
#       6 contenu_repare = contenu.rstrip().rstrip(',') + ']'
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\TonNom\\Desktop\\price-intelligence-platform\\scrapers\\data\\avito_2026-03-30T12-08-43+00-00.json'

# %%
import json

with open(r'C:\Users\hp\Desktop\price-intelligence-platform\scrapers\data\avito_2026-03-30T12-08-43+00-00.json', 'r', encoding='utf-8') as f:
    contenu = f.read()

contenu_repare = contenu.rstrip().rstrip(',') + ']'

try:
    donnees = json.loads(contenu_repare)
    print(f"✅ {len(donnees)} entrées récupérées")
    
    with open(r'C:\Users\TonNom\Desktop\avito_repare.json', 'w', encoding='utf-8') as f:
        json.dump(donnees, f, ensure_ascii=False, indent=2)
except Exception as e:
    print(f"❌ Erreur : {e}")
# Out:
# ✅ 134 entrées récupérées
# ❌ Erreur : [Errno 2] No such file or directory: 'C:\\Users\\TonNom\\Desktop\\avito_repare.json'

# %%
import os
print(os.path.expanduser("~"))
# Out:
# C:\Users\hp
